# %%
df = spark.read.table("databricks_cata.bronze.regions")

# %%
df.display()

# %%
df= df.drop("_rescued_data")
df.display()

# %%
df.write.format("delta").mode("overwrite")\
    .save("abfss://silver@databricksstorageadls.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta").load("abfss://silver@databricksstorageadls.dfs.core.windows.net/orders")
df.display()

# %%
# %sql
create table if not exists databricks_cata.silver.region_silver
using delta
location "abfss://silver@databricksstorageadls.dfs.core.windows.net/regions"

# %%
# %sql
select * from databricks_cata.silver.region_silver
